# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy


# Import the time library 
import time


# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Create counters.
record_count = 1
set_count = 1



# Create an empty list to hold the weather data.
city_WeatherPy_Data= []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]

        
       
        
        # Append the city information into city_data list.
        city_WeatherPy_Data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "weather Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | tiksi
# Processing Record 2 of Set 1 | yumen
# Processing Record 3 of Set 1 | mar del plata
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | arraial do cabo
# Processing Record 6 of Set 1 | talnakh
# Processing Record 7 of Set 1 | pangai
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | coihaique
# Processing Record 11 of Set 1 | dhidhdhoo
# Processing Record 12 of Set 1 | mogadishu
# Processing Record 13 of Set 1 | svetlyy
# Processing Record 14 of Set 1 | aniva
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | luderitz
# Processing Record 18 of Set 1 | san giuseppe jato
# Processing Record 19 of Set 1 | mahebourg
# Processing Record 20 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | ixtapa
# Processing Record 23 of Set 1 | labuhan
# Processing Record 24 of Set 1 | hornepayne
# Processing Record 25 of Set 1 | new norfolk
# Processing Record 26 of Set 1 | beringovskiy
# Processing Record 27 of Set 1 | rocha
# Processing Record 28 of Set 1 | dikson
# Processing Record 29 of Set 1 | dingle
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | esperance
# Processing Record 32 of Set 1 | ust-nera
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | quelimane
# Processing Record 35 of Set 1 | bastrop
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | nara
# Processing Record 38 of Set 1 | sitka
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | castro
# Processing Record 41 of Set 1 | plettenberg bay
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | gat
# Processing Record 44 of Set 1 | lahat
# Processing Record 45 of Set 1 | huarmey
# Processing Record 46 of Set 1 | galle
# Processing Record 47 of Set 1 | zapolyarnyy
# Processing Record 48 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 1 | mindelo
# Processing Record 50 of Set 1 | avarua
# Processing Record 1 of Set 2 | padang
# Processing Record 2 of Set 2 | norman wells
# Processing Record 3 of Set 2 | ribeira grande
# Processing Record 4 of Set 2 | port alfred
# Processing Record 5 of Set 2 | bilibino
# Processing Record 6 of Set 2 | ampanihy
# Processing Record 7 of Set 2 | pizhanka
# Processing Record 8 of Set 2 | hilo
# Processing Record 9 of Set 2 | cherskiy
# Processing Record 10 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 2 | winneba
# Processing Record 12 of Set 2 | butembo
# Processing Record 13 of Set 2 | qaanaaq
# Processing Record 14 of Set 2 | batticaloa
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | awjilah
# Processing Record 17 of Set 2 | hermanus
# Processing Record 18 of Set 2 | kahului
# Processing Record 19 of Set 2 | ilulissat
# Processing Record 20 of Set 2 | avera
# Processing Record 21 of Set 2 | beloha
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | bredasdorp
# Processing Record 24 of Set 2 | leczna
# Processing Record 25 of Set 2 | valdivia
# Processing Record 26 of Set 2 | plainview
# Processing Record 27 of Set 2 | jardim
# Processing Record 28 of Set 2 | laguna
# Processing Record 29 of Set 2 | tomatlan
# Processing Record 30 of Set 2 | palauig
# Processing Record 31 of Set 2 | thompson
# Processing Record 32 of Set 2 | noyabrsk
# Processing Record 33 of Set 2 | nueve de julio
# Processing Record 34 of Set 2 | carnarvon
# Processing Record 35 of Set 2 | nanchang
# Processing Record 36 of Set 2 | dodge city
# Processing Record 37 of Set 2 | victoria
# Processing Record 38 of Set 2 | viedma
# Processing Record 39 of Set 2 | zakamensk
# Processing Record 40 of Set 2 | saskylakh
# Processing Record 41 of Set 2 | clyde river
# Processing Record 42 of Set 2 | faanui
# Processing Record 43 of Set 2 | ambilobe
# Processing Record 44 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 2 | cabo san lucas
# Processing Record 46 of Set 2 | poli
# Processing Record 47 of Set 2 | alyangula
# Processing Record 48 of Set 2 | cork
# Processing Record 49 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 3 | vao
# Processing Record 2 of Set 3 | bethel
# Processing Record 3 of Set 3 | moultrie
# Processing Record 4 of Set 3 | iqaluit
# Processing Record 5 of Set 3 | sept-iles
# Processing Record 6 of Set 3 | mangrol
# Processing Record 7 of Set 3 | cape town
# Processing Record 8 of Set 3 | east london
# Processing Record 9 of Set 3 | saldanha
# Processing Record 10 of Set 3 | pangody
# Processing Record 11 of Set 3 | kitimat
# Processing Record 12 of Set 3 | vardo
# Processing Record 13 of Set 3 | upernavik
# Processing Record 14 of Set 3 | burica
# City not found. Skipping...
# Processing Record 15 of Set 3 | mentok
# City not found. Skipping...
# Processing Record 16 of Set 3 | olafsvik
# Processing Record 17 of Set 3 | villazon
# Processing Record 18 of Set 3 | lorengau
# Processing Record 19 of Set 3 | ostrovnoy
# Processing Record 20 of Set 3 | butaritari
# Processing Record 21 of Set 3 | hithadhoo
# Processing Record 22 of Set 3 | chenghai
# Processing Record 23 of Set 3 | nanakuli
# Processing Record 24 of Set 3 | praya
# Processing Record 25 of Set 3 | duku
# Processing Record 26 of Set 3 | barrow
# Processing Record 27 of Set 3 | russell
# Processing Record 28 of Set 3 | bengkulu
# Processing Record 29 of Set 3 | severo-kurilsk
# Processing Record 30 of Set 3 | flinders
# Processing Record 31 of Set 3 | port hedland
# Processing Record 32 of Set 3 | wuwei
# Processing Record 33 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 34 of Set 3 | torbay
# Processing Record 35 of Set 3 | kalmunai
# Processing Record 36 of Set 3 | newport
# Processing Record 37 of Set 3 | asau
# Processing Record 38 of Set 3 | bluff
# Processing Record 39 of Set 3 | mount darwin
# Processing Record 40 of Set 3 | ahipara
# Processing Record 41 of Set 3 | voh
# Processing Record 42 of Set 3 | qiyang
# Processing Record 43 of Set 3 | azimur
# City not found. Skipping...
# Processing Record 44 of Set 3 | pointe michel
# Processing Record 45 of Set 3 | mackay
# Processing Record 46 of Set 3 | katsuura
# Processing Record 47 of Set 3 | harper
# Processing Record 48 of Set 3 | honiara
# Processing Record 49 of Set 3 | cidreira
# Processing Record 50 of Set 3 | khatanga
# Processing Record 1 of Set 4 | puerto leguizamo
# Processing Record 2 of Set 4 | nishihara
# Processing Record 3 of Set 4 | mehamn
# Processing Record 4 of Set 4 | kargil
# Processing Record 5 of Set 4 | nikolskoye
# Processing Record 6 of Set 4 | valdosta
# Processing Record 7 of Set 4 | tuktoyaktuk
# Processing Record 8 of Set 4 | port elizabeth
# Processing Record 9 of Set 4 | egvekinot
# Processing Record 10 of Set 4 | nanortalik
# Processing Record 11 of Set 4 | nicoya
# Processing Record 12 of Set 4 | bichena
# Processing Record 13 of Set 4 | kawalu
# Processing Record 14 of Set 4 | kaitangata
# Processing Record 15 of Set 4 | acapulco
# Processing Record 16 of Set 4 | langham
# Processing Record 17 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 4 | yashalta
# Processing Record 19 of Set 4 | souillac
# Processing Record 20 of Set 4 | airai
# Processing Record 21 of Set 4 | pemangkat
# Processing Record 22 of Set 4 | sampit
# Processing Record 23 of Set 4 | eenhana
# Processing Record 24 of Set 4 | nakamura
# Processing Record 25 of Set 4 | karratha
# Processing Record 26 of Set 4 | husavik
# Processing Record 27 of Set 4 | bathsheba
# Processing Record 28 of Set 4 | sao domingos
# Processing Record 29 of Set 4 | vestmannaeyjar
# Processing Record 30 of Set 4 | brae
# Processing Record 31 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 32 of Set 4 | ende
# Processing Record 33 of Set 4 | oistins
# Processing Record 34 of Set 4 | hualmay
# Processing Record 35 of Set 4 | purpe
# Processing Record 36 of Set 4 | aklavik
# Processing Record 37 of Set 4 | elko
# Processing Record 38 of Set 4 | saint-philippe
# Processing Record 39 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 4 | ishigaki
# Processing Record 41 of Set 4 | payakumbuh
# Processing Record 42 of Set 4 | monrovia
# Processing Record 43 of Set 4 | roma
# Processing Record 44 of Set 4 | erzin
# Processing Record 45 of Set 4 | noumea
# Processing Record 46 of Set 4 | mildura
# Processing Record 47 of Set 4 | port-gentil
# Processing Record 48 of Set 4 | bukachacha
# Processing Record 49 of Set 4 | guadalupe victoria
# Processing Record 50 of Set 4 | pevek
# Processing Record 1 of Set 5 | narsaq
# Processing Record 2 of Set 5 | saint-augustin
# Processing Record 3 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 5 | codrington
# Processing Record 6 of Set 5 | chickasha
# Processing Record 7 of Set 5 | berlevag
# Processing Record 8 of Set 5 | ciudad bolivar
# Processing Record 9 of Set 5 | koungou
# Processing Record 10 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 5 | mugur-aksy
# Processing Record 12 of Set 5 | chadan
# Processing Record 13 of Set 5 | dutlwe
# Processing Record 14 of Set 5 | khasan
# Processing Record 15 of Set 5 | diapaga
# Processing Record 16 of Set 5 | necochea
# Processing Record 17 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 18 of Set 5 | pangnirtung
# Processing Record 19 of Set 5 | hoa binh
# Processing Record 20 of Set 5 | anastasiyevskaya
# Processing Record 21 of Set 5 | visnes
# Processing Record 22 of Set 5 | safaga
# Processing Record 23 of Set 5 | daxian
# City not found. Skipping...
# Processing Record 24 of Set 5 | ojinaga
# Processing Record 25 of Set 5 | yulara
# Processing Record 26 of Set 5 | klaksvik
# Processing Record 27 of Set 5 | richards bay
# Processing Record 28 of Set 5 | kozan
# Processing Record 29 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 5 | nezhinka
# Processing Record 31 of Set 5 | nome
# Processing Record 32 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 33 of Set 5 | sorland
# Processing Record 34 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 5 | leningradskiy
# Processing Record 36 of Set 5 | unity
# Processing Record 37 of Set 5 | flin flon
# Processing Record 38 of Set 5 | kamenka
# Processing Record 39 of Set 5 | weligama
# Processing Record 40 of Set 5 | otradnoye
# Processing Record 41 of Set 5 | valparaiso
# Processing Record 42 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 5 | piacabucu
# Processing Record 44 of Set 5 | camacha
# Processing Record 45 of Set 5 | naze
# Processing Record 46 of Set 5 | cabra
# Processing Record 47 of Set 5 | lagoa
# Processing Record 48 of Set 5 | vila franca do campo
# Processing Record 49 of Set 5 | verkhnetulomskiy
# Processing Record 50 of Set 5 | hami
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12476/746122198.py in <module>
#       9         set_count += 1
#      10         record_count = 1
# ---> 11         time.sleep(60)
#      12
#      13     # Create endpoint URL with each city.
#
# KeyboardInterrupt:

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
WeatherPy_Database_df= pd.DataFrame(city_WeatherPy_Data)
WeatherPy_Database_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Tiksi      RU  71.6872  128.8694    -11.99        93         100
# 1            Yumen      CN  40.2833   97.2000     23.23        42         100
# 2    Mar Del Plata      AR -38.0023  -57.5575     75.22        69           0
# 3        Jamestown      US  42.0970  -79.2353     49.32        65         100
# 4  Arraial Do Cabo      BR -22.9661  -42.0278     73.36        83          75
# 5          Talnakh      RU  69.4865   88.3972     -5.80        98         100
# 6           Pangai      TO -19.8000 -174.3500     82.51        74          20
# 7            Vaini      TO -21.2000 -175.2000     82.56        89          20
# 8     Punta Arenas      CL -53.1500  -70.9167     51.91        50          75
# 9        Coihaique      CL -45.5752  -72.0662     66.81        30          40
#
#    Wind Speed weather Description
# 0       13.42     overcast clouds
# 1       12.37     overcast clouds
# 2       14.97           clear sky
# 3       12.66     overcast clouds
# 4        5.75       broken clouds
# 5       11.01          light snow
# 6        9.22          few clouds
# 7        9.22          few clouds
# 8       31.07       broken clouds
# 9       10.36    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
WeatherPy_Database_df.to_csv(output_data_file, index_label="City_ID")
